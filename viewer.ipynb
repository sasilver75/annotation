# %%
import pandas as pd

# %%
dt_196 = pd.read_csv("Ubuntu-dialogue-corpus/dialogueText_196.csv")

# %%
dt_301 = pd.read_csv("Ubuntu-dialogue-corpus/dialogueText_301.csv")

# %%
dt = pd.read_csv("Ubuntu-dialogue-corpus/dialogueText.csv")

# %%
toc = pd.read_csv("toc.csv")

# %%
multidogo = pd.read_csv("MultiDoGO.tsv", 
                    #    sep="\t",
                       on_bad_lines='skip',  # Skip problematic lines
                       quoting=3)            # QUOTE_NONE - disable quote character

# %%
print(f"Length of dt_196: {len(dt_196)}")
print(f"Length of dt_301: {len(dt_301)}")
print(f"Length of dt: {len(dt)}")
print(f"Length of toc: {len(toc)}")
print(f"Length of multidogo: {len(multidogo)}")
# Out:
# Length of dt_196: 9212877
# Length of dt_301: 16587830
# Length of dt: 1038324
# Length of toc: 3
# Length of multidogo: 74333

# %%
toc.head()
# Out:
#       lines      words  characters              filename
# 0   9212878   91660344   996253904  dialogueText_196.csv
# 1  16587831  166392849  1799936480  dialogueText_301.csv
# 2   1038325   11035331   116070597      dialogueText.csv

# %%
multidogo[multidogo["conversationId"] == "acs-00ad5526-bb84-4148-ac30-19afca56c12b-1"]
# Out:
#                                 conversationId turnNumber  \
# 79  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1          0
# 80  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1          1
# 81  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1          2
# 82  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1          3
# 83  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1          5
# 84  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1          7
# 85  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1          9
# 86  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1         11
# 87  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1         12
# 88  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1         13
# 89  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1         14
# 90  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1         16
# 91  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1         18
# 92  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1         19
# 93  acs-00ad5526-bb84-4148-ac30-19afca56c12b-1         20
# ...

# %%
multidogo[multidogo["conversationId"] == "acs-629291d6-ca2b-4b63-aaf7-012ef4f602c9-1"]
# Out:
#                                  conversationId turnNumber  \
# 122  acs-629291d6-ca2b-4b63-aaf7-012ef4f602c9-1          0
# 123  acs-629291d6-ca2b-4b63-aaf7-012ef4f602c9-1          1
# 124  acs-629291d6-ca2b-4b63-aaf7-012ef4f602c9-1          2
# 125  acs-629291d6-ca2b-4b63-aaf7-012ef4f602c9-1          4
# 126  acs-629291d6-ca2b-4b63-aaf7-012ef4f602c9-1          9
# 127  acs-629291d6-ca2b-4b63-aaf7-012ef4f602c9-1         13
#
#                                   utteranceId  \
# 122  acs-bdcc89ca-c1bf-42c1-b4f2-c9b5487f3b3a
# 123  acs-932cccbc-881a-4ab3-868e-c9716f1ebc2d
# 124  acs-f63a4730-a0c8-4ab6-b98c-2e188ddc97d6
# 125  acs-b7d23425-b675-4b82-9e81-0b4883dabaaf
# 126  acs-4e128758-95a1-420f-93b3-c1929f67bc7e
# 127  acs-5e083012-ad3e-4453-b6bf-e5739d5efd8f
#
#                                              utterance authorRole
# 122                                              Hello   customer
# 123  Hello! Welcome to ACS Software Solutions. How ...      agent
# ...

# %%
multidogo[multidogo["conversationId"] == "acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1"]
# Out:
#                                  conversationId turnNumber  \
# 170  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          0
# 172  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          2
# 174  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          3
# 176  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          4
# 177  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          5
# 179  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          6
# 180  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          7
# 182  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          8
# 183  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1          9
# 185  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1         10
# 186  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1         11
# 188  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1         12
# 189  acs-b5a66197-127c-4bd1-8946-8813b9cbdeb8-1         13
#
#                                   utteranceId  \
# 170  acs-5d9da0c4-abb6-4f12-b01a-6b40684c8c6a
# ...

# %%
multidogo[multidogo["conversationId"] == "acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1"]
# Out:
#                                  conversationId turnNumber  \
# 234  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          0
# 235  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          1
# 236  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          2
# 237  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          3
# 238  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          4
# 239  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          5
# 240  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          6
# 241  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          7
# 242  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1          9
# 243  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1         10
# 244  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1         11
# 245  acs-1d1dbfa6-4e53-44cc-b748-5e3a44b92508-1         12
#
#                                   utteranceId  \
# 234  acs-6123b525-4030-4b17-a0f6-fb429a0ebb9c
# 235  acs-ba3aae84-d860-4050-9083-695961bdda1e
# 236  acs-87e0dcaa-6074-47ca-82ab-ba65b75f510d
# ...

# %%
multidogo[multidogo["conversationId"] == "acs-4463829b-6d87-477a-a882-d6cd78a6056b-1"]
# Out:
#                                  conversationId turnNumber  \
# 476  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          0
# 477  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          1
# 478  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          2
# 479  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          3
# 481  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          4
# 482  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          5
# 483  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          6
# 484  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          7
# 485  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          8
# 486  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1          9
# 487  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1         11
# 488  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1         13
# 489  acs-4463829b-6d87-477a-a882-d6cd78a6056b-1         14
#
#                                   utteranceId  \
# 476  acs-0e9caa4f-cf63-4f45-b155-98ab2657d7a8
# ...

# %%
# print(dt_196["dialogueID"].unique())
# print(dt_196["folder"].unique())
# print(99 in dt_196["folder"].unique())
dt_196[(dt_196["folder"] == 99) & (dt_196["dialogueID"] == "92.tsv")].to_clipboard()
# dt_196.head()
# print(f"Length: {len(dt_196[dt_196['dialogueID'] == '92.tsv'])}")
# dt_196[dt_196["dialogueID"] == "92.tsv"]

# %%
dt_301.head()
# Out:
#    folder dialogueID                      date     from       to  \
# 0     301      1.tsv  2004-11-23T11:49:00.000Z  stuNNed      NaN
# 1     301      1.tsv  2004-11-23T11:49:00.000Z  crimsun  stuNNed
# 2     301      1.tsv  2004-11-23T11:49:00.000Z  stuNNed  crimsun
# 3     301      1.tsv  2004-11-23T11:49:00.000Z  crimsun  stuNNed
# 4     301      1.tsv  2004-11-23T11:50:00.000Z  stuNNed  crimsun
#
#                                                 text
# 0   any ideas why java plugin takes so long to load?
# 1                                          java 1.4?
# 2                                                yes
# 3                       java 1.5 loads _much_ faster
# 4  noneus: how can i get 1.5 is there a .deb some...

# %%
dt.head()
# Out:
#    folder  dialogueID                      date       from         to  \
# 0       3  126125.tsv  2008-04-23T14:55:00.000Z  bad_image        NaN
# 1       3  126125.tsv  2008-04-23T14:56:00.000Z  bad_image        NaN
# 2       3  126125.tsv  2008-04-23T14:57:00.000Z  lordleemo  bad_image
# 3       3   64545.tsv  2009-08-01T06:22:00.000Z   mechtech        NaN
# 4       3   64545.tsv  2009-08-01T06:22:00.000Z   mechtech        NaN
#
#                                                 text
# 0  Hello folks, please help me a bit with the fol...
# 1  Did I choose a bad channel? I ask because you ...
# 2  the second sentence is better english   and we...
# 3                                       Sock Puppe?t
# 4                                               WTF?
